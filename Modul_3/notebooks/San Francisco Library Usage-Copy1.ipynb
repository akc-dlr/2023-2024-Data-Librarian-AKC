# %%
import pandas as pd
import json

# %%
data = pd.read_csv("/home/anni/Schreibtisch/2023-2024-Data-Librarian-AKC/Modul_3/data/Library_Usage.csv")
# Out:
# /tmp/ipykernel_1035736/3676822830.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/home/anni/Schreibtisch/2023-2024-Data-Librarian-AKC/Modul_3/data/Library_Usage.csv")

# %%
data
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# ...

# %%
data.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Within San Francisco County'],
#       dtype='object')

# %%
age_filter = (data['Age Range'] == '60 to 64 years')

# %%
filtered_age = data.loc[age_filter]

# %%
filtered_age
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 11                     5                  Staff              146
# 26                     5                  Staff              843
# 48                     0                  Adult               41
# 90                     0                  Adult                0
# 137                   16    Digital Access Card                0
# ...                  ...                    ...              ...
# 436197                 0                  Adult                0
# 436217                 0                  Adult                0
# 436236                 0                  Adult                2
# 436260                 0                  Adult              172
# 436287                 0                  Adult                6
#
#         Total Renewals       Age Range Home Library Code  \
# 11                 259  60 to 64 years                 x
# 26                 234  60 to 64 years                 x
# ...

# %%
data['Circulation Active Year'].unique()
# Out:
# array([2023., 2020., 2018., 2022., 2019., 2021.,   nan, 2017., 2014.,
#        2011., 2009., 2016., 2015., 2007., 2013., 2010., 2012., 2006.,
#        2005., 2008., 2004.])

# %%
filtered_age['Circulation Active Year'] == 'Richmond')

# %%
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 436285    False
# 436286    False
# 436287     True
# 436288    False
# 436289    False
# Name: Age Range, Length: 436290, dtype: bool

# %%
data.loc[loc_filter]
