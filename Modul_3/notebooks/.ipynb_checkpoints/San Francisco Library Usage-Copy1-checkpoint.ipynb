# %%
import pandas as pd
import json

# %%
data = pd.read_csv("/home/anni/Schreibtisch/2023-2024-Data-Librarian-AKC/Modul_3/data/Library_Usage.csv")
# Out:
# /tmp/ipykernel_98343/3676822830.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/home/anni/Schreibtisch/2023-2024-Data-Librarian-AKC/Modul_3/data/Library_Usage.csv")

# %%
data
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# 2                   33     45 to 54 years                n4
# 3                 2140                NaN                o2
# 4                 1035                NaN                o7
# ...                ...                ...               ...
# 436285               6     35 to 44 years               yjj
# 436286               0     10 to 19 years               yjj
# 436287               0     60 to 64 years               ylw
# 436288               0     35 to 44 years               ylw
# 436289             101  75 years and over               ylw
#
#        Home Library Definition Circulation Active Month  \
# 0                      Bayview                      Mar
# 1                    Excelsior                      Jun
# 2                   Noe Valley                      Jan
# 3                   Ocean View                      Jul
# 4                       Ortega                      Jul
# ...                        ...                      ...
# 436285              Bookmobile                      Oct
# 436286              Bookmobile                      Nov
# 436287              Bookmobile                      Mar
# 436288              Bookmobile                      Sep
# 436289              Bookmobile                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 0                        2023.0                      z
# 1                        2023.0                      z
# 2                        2023.0                      z
# 3                        2023.0                      z
# 4                        2023.0                      z
# ...                         ...                    ...
# 436285                   2022.0                      z
# 436286                   2015.0                      z
# 436287                   2022.0                      z
# 436288                   2020.0                      z
# 436289                   2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 0                             Email                    True
# 1                             Email                    True
# 2                             Email                    True
# 3                             Email                    True
# 4                             Email                    True
# ...                             ...                     ...
# 436285                        Email                    True
# 436286                        Email                    True
# 436287                        Email                    True
# 436288                        Email                    True
# 436289                        Email                    True
#
#         Year Patron Registered Within San Francisco County
# 0                         2003                       False
# 1                         2003                       False
# 2                         2011                       False
# 3                         2003                       False
# 4                         2003                       False
# ...                        ...                         ...
# 436285                    2020                         NaN
# 436286                    2011                         NaN
# 436287                    2022                         NaN
# 436288                    2019                         NaN
# 436289                    2003                         NaN
#
# [436290 rows x 14 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# 2                   33     45 to 54 years                n4
# 3                 2140                NaN                o2
# 4                 1035                NaN                o7
# ...                ...                ...               ...
# 436285               6     35 to 44 years               yjj
# 436286               0     10 to 19 years               yjj
# 436287               0     60 to 64 years               ylw
# 436288               0     35 to 44 years               ylw
# 436289             101  75 years and over               ylw
#
#        Home Library Definition Circulation Active Month  \
# 0                      Bayview                      Mar
# 1                    Excelsior                      Jun
# 2                   Noe Valley                      Jan
# 3                   Ocean View                      Jul
# 4                       Ortega                      Jul
# ...                        ...                      ...
# 436285              Bookmobile                      Oct
# 436286              Bookmobile                      Nov
# 436287              Bookmobile                      Mar
# 436288              Bookmobile                      Sep
# 436289              Bookmobile                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 0                        2023.0                      z
# 1                        2023.0                      z
# 2                        2023.0                      z
# 3                        2023.0                      z
# 4                        2023.0                      z
# ...                         ...                    ...
# 436285                   2022.0                      z
# 436286                   2015.0                      z
# 436287                   2022.0                      z
# 436288                   2020.0                      z
# 436289                   2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 0                             Email                    True
# 1                             Email                    True
# 2                             Email                    True
# 3                             Email                    True
# 4                             Email                    True
# ...                             ...                     ...
# 436285                        Email                    True
# 436286                        Email                    True
# 436287                        Email                    True
# 436288                        Email                    True
# 436289                        Email                    True
#
#         Year Patron Registered Within San Francisco County
# 0                         2003                       False
# 1                         2003                       False
# 2                         2011                       False
# 3                         2003                       False
# 4                         2003                       False
# ...                        ...                         ...
# 436285                    2020                         NaN
# 436286                    2011                         NaN
# 436287                    2022                         NaN
# 436288                    2019                         NaN
# 436289                    2003                         NaN
#
# [436290 rows x 14 columns]>

# %%
data.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_577035/107731030.py in ?()
# ----> 1 data.rows
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
len(data)
# Out:
# 436290

# %% [markdown]
# 2.1 Grundbegriffe (60 Min)
#
# Beantworte und diskutiere die folgenden Fragen konkret für den in Einheit 1 heruntergeladenen San Francisco Library Usage Datensatz. Notiere Deine Ergebnisse in Stichpunkte.
#
#     Wie viele Merkmale besitzt der Datensatz?
#     14
#
#     Wie groß ist die Stichprobengröße des Datensatzes?
#     436.290 (jeder Eintrag ein Nutzender)
#
#     Wer oder was sind die Merkmalsträger?
#     Aktive Nutzende nach Definition
#
#     Von wann bis wann wurden die Daten erhoben?
#     2016 - 2023
#
#     Wie lässt sich die Grundgesamtheit beschreiben? Handelt es sich um eine Vollerhebung?
#     Grundgesamtheit = alle potenziell Nutzenden. Keine Vollerhebung
#
#
#     Welche Merkmale sind stetig? Welche diskret?
#     stetig: Age Range (ist aber gruppiert)
#
#     Welchem Skalenniveau entsprechen die einzelnen Merkmale (Nominal-, Ordinal- oder Metrische Skala)?
#     Patron Type Code, Patron Type Definition, Home Library Code, Home Library Definition, Circulation Active Month 	Circulation Active Year, Notice Preference Code, Notice Preference Definition, Provided Email Address, Year Patron Registered, Within San Francisco County = nominal
#     Total Checkouts 	Total Renewals = metrisch
#
#
#
#     Enthält der Datensatz fehlende Werte?
#     ja (NaN Einträge)
#
#     Handelt es sich um Querschnitts-, Längsschnitss- oder Paneldaten?
#     Längsschnitt

# %% [markdown]
# 2.6 Filtern (30 Min)
#
#     Filtere den Datensatz nach Kindern unter 10 Jahren. Wie viele Einträge erhältst Du? 32692
#     Gibt es Personen mit mehr als 20000 Ausleihen? ja
#     Wie viele Personen stammen aus dem Stadtteil (Richmond)? 20656
#     Wie viele Prozent der Beobachtungen haben eine Membership Duration von Null Monaten?

# %%
data.loc[data['Total Checkouts'] > 20000]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 51592                  3                 Senior            22934
# 74783                  3                 Senior            21890
# 95369                  3                 Senior            20411
# 95967                  3                 Senior            20351
# 192830                 0                  Adult            23706
# 198191                 0                  Adult            37249
# 278966                 0                  Adult            33122
# 354659                 0                  Adult            22187
# 375195                 0                  Adult            45380
#
#         Total Renewals          Age Range Home Library Code  \
# 51592              583     65 to 74 years                 x
# 74783               16  75 years and over                 x
# 95369             2606     65 to 74 years                 x
# 95967              902     65 to 74 years                 x
# 192830             384     45 to 54 years                c2
# 198191             628     55 to 59 years                o7
# 278966              57     25 to 34 years                s7
# 354659            5706     55 to 59 years                c2
# 375195             143     35 to 44 years                v3
#
#        Home Library Definition Circulation Active Month  \
# 51592                     Main                      Jul
# 74783                     Main                      Jan
# 95369                     Main                      Aug
# 95967                     Main                      Jul
# 192830               Chinatown                      Jul
# 198191                  Ortega                      Jul
# 278966                  Sunset                      Jul
# 354659               Chinatown                      Jul
# 375195       Visitacion Valley                      Dec
#
#         Circulation Active Year Notice Preference Code  \
# 51592                    2023.0                    NaN
# 74783                    2023.0                      z
# 95369                    2019.0                    NaN
# 95967                    2023.0                    NaN
# 192830                   2023.0                    NaN
# 198191                   2023.0                      z
# 278966                   2023.0                      z
# 354659                   2023.0                      z
# 375195                   2020.0                    NaN
#
#        Notice Preference Definition  Provided Email Address  \
# 51592                           NaN                   False
# 74783                         Email                    True
# 95369                           NaN                   False
# 95967                           NaN                   False
# 192830                          NaN                   False
# 198191                        Email                    True
# 278966                        Email                    True
# 354659                        Email                    True
# 375195                          NaN                   False
#
#         Year Patron Registered Within San Francisco County
# 51592                     2003                       False
# 74783                     2005                       False
# 95369                     2003                       False
# 95967                     2004                       False
# 192830                    2003                       False
# 198191                    2003                       False
# 278966                    2010                       False
# 354659                    2003                       False
# 375195                    2003                       False

# %%
print(['Patron Type Definition'])
# Out:
# ['Patron Type Definition']

# %%
print(data.rows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_98343/3387299037.py in ?()
# ----> 1 print(data.rows)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
data.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Within San Francisco County'],
#       dtype='object')

# %%
data['Patron Type Definition'].unique()
# Out:
# array(['Staff', 'Welcome', 'Visitor', 'Digital Access Card', 'Juvenile',
#        'Senior', 'Adult', 'Teen', 'Retired Staff', 'Teacher Card',
#        'At User Adult', 'At User Senior', 'At User Welcome',
#        'At User Teen', 'Business', 'Library By Mail', 'At User Juvenile'],
#       dtype=object)

# %% [raw]
# row_filter = (data['Patron Type Definition'] == 'Juvenile')

# %%
row_filter
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 436285    False
# 436286    False
# 436287    False
# 436288    False
# 436289    False
# Name: Patron Type Definition, Length: 436290, dtype: bool

# %%
len(row_filter)
# Out:
# 436290

# %%
data.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 39                     1               Juvenile              108
# 45                     1               Juvenile                0
# 46                     1               Juvenile                2
# 47                     1               Juvenile               48
# 60                     1               Juvenile                0
# ...                  ...                    ...              ...
# 436164                 1               Juvenile                0
# 436176                 1               Juvenile                7
# 436243                 1               Juvenile                0
# 436253                 1               Juvenile                0
# 436281                 1               Juvenile                1
#
#         Total Renewals       Age Range Home Library Code  \
# 39                 108    0 to 9 years                o7
# 45                   0    0 to 9 years                 x
# 46                   0  10 to 19 years                 x
# 47                  33    0 to 9 years                o7
# 60                   0    0 to 9 years                g6
# ...                ...             ...               ...
# 436164               0    0 to 9 years                 x
# 436176              21    0 to 9 years                 x
# 436243               0  10 to 19 years                 x
# 436253               0    0 to 9 years                 x
# 436281               1    0 to 9 years                 x
#
#        Home Library Definition Circulation Active Month  \
# 39                      Ortega                      Jul
# 45                        Main                      NaN
# 46                        Main                      Oct
# 47                      Ortega                      Jul
# 60          Golden Gate Valley                      Jul
# ...                        ...                      ...
# 436164                    Main                      NaN
# 436176                    Main                      Jan
# 436243                    Main                      NaN
# 436253                    Main                      NaN
# 436281                    Main                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 39                       2023.0                      z
# 45                          NaN                      z
# 46                       2019.0                      z
# 47                       2021.0                      z
# 60                       2022.0                      z
# ...                         ...                    ...
# 436164                      NaN                      z
# 436176                   2020.0                      z
# 436243                      NaN                    NaN
# 436253                      NaN                    NaN
# 436281                   2023.0                    NaN
#
#        Notice Preference Definition  Provided Email Address  \
# 39                            Email                    True
# 45                            Email                    True
# 46                            Email                    True
# 47                            Email                    True
# 60                            Email                    True
# ...                             ...                     ...
# 436164                        Email                    True
# 436176                        Email                    True
# 436243                          NaN                   False
# 436253                          NaN                   False
# 436281                          NaN                   False
#
#         Year Patron Registered Within San Francisco County
# 39                        2021                       False
# 45                        2021                       False
# 46                        2019                       False
# 47                        2018                       False
# 60                        2022                       False
# ...                        ...                         ...
# 436164                    2023                         NaN
# 436176                    2019                         NaN
# 436243                    2023                         NaN
# 436253                    2023                         NaN
# 436281                    2023                         NaN
#
# [53281 rows x 14 columns]

# %%
data['Age Range'].unique()
# Out:
# array([nan, '45 to 54 years', '55 to 59 years', '60 to 64 years',
#        '25 to 34 years', '35 to 44 years', '20 to 24 years',
#        '75 years and over', '10 to 19 years', '0 to 9 years',
#        '65 to 74 years'], dtype=object)

# %%
age_filter = (data['Age Range'] == '0 to 9 years')

# %%
data.loc[age_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 39                     1               Juvenile              108
# 45                     1               Juvenile                0
# 47                     1               Juvenile               48
# 60                     1               Juvenile                0
# 86                     1               Juvenile                0
# ...                  ...                    ...              ...
# 436151                 1               Juvenile                0
# 436164                 1               Juvenile                0
# 436176                 1               Juvenile                7
# 436253                 1               Juvenile                0
# 436281                 1               Juvenile                1
#
#         Total Renewals     Age Range Home Library Code  \
# 39                 108  0 to 9 years                o7
# 45                   0  0 to 9 years                 x
# 47                  33  0 to 9 years                o7
# 60                   0  0 to 9 years                g6
# 86                   0  0 to 9 years                 x
# ...                ...           ...               ...
# 436151               0  0 to 9 years                 x
# 436164               0  0 to 9 years                 x
# 436176              21  0 to 9 years                 x
# 436253               0  0 to 9 years                 x
# 436281               1  0 to 9 years                 x
#
#        Home Library Definition Circulation Active Month  \
# 39                      Ortega                      Jul
# 45                        Main                      NaN
# 47                      Ortega                      Jul
# 60          Golden Gate Valley                      Jul
# 86                        Main                      NaN
# ...                        ...                      ...
# 436151                    Main                      NaN
# 436164                    Main                      NaN
# 436176                    Main                      Jan
# 436253                    Main                      NaN
# 436281                    Main                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 39                       2023.0                      z
# 45                          NaN                      z
# 47                       2021.0                      z
# 60                       2022.0                      z
# 86                          NaN                      z
# ...                         ...                    ...
# 436151                      NaN                      z
# 436164                      NaN                      z
# 436176                   2020.0                      z
# 436253                      NaN                    NaN
# 436281                   2023.0                    NaN
#
#        Notice Preference Definition  Provided Email Address  \
# 39                            Email                    True
# 45                            Email                    True
# 47                            Email                    True
# 60                            Email                    True
# 86                            Email                    True
# ...                             ...                     ...
# 436151                        Email                    True
# 436164                        Email                    True
# 436176                        Email                    True
# 436253                          NaN                   False
# 436281                          NaN                   False
#
#         Year Patron Registered Within San Francisco County
# 39                        2021                       False
# 45                        2021                       False
# 47                        2018                       False
# 60                        2022                       False
# 86                        2023                       False
# ...                        ...                         ...
# 436151                    2021                         NaN
# 436164                    2023                         NaN
# 436176                    2019                         NaN
# 436253                    2023                         NaN
# 436281                    2023                         NaN
#
# [32692 rows x 14 columns]

# %%
data['Home Library Definition'].unique()
# Out:
# array(['Bayview', 'Excelsior', 'Noe Valley', 'Ocean View', 'Ortega',
#        'West Portal', 'Main', 'Glen Park', 'Anza', 'Presidio', 'Portola',
#        'North Beach', 'Golden Gate Valley', 'Richmond', 'Park', 'Marina',
#        'Sunset', 'Potrero', 'Mission', 'Eureka Valley', 'Merced',
#        'Chinatown', 'Mission Bay', 'Western Addition', 'Bernal',
#        'Visitacion Valley', 'Parkside', 'Ingleside', 'Bookmobile', nan],
#       dtype=object)

# %%
loc_filter = (data['Home Library Definition'] == 'Richmond')

# %%
data.loc[loc_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 42                    10                Visitor                9
# 53                     0                  Adult              838
# 83                     0                  Adult                1
# 118                    4                Welcome                0
# 163                   10                Visitor               27
# ...                  ...                    ...              ...
# 435822                16    Digital Access Card                0
# 435823                 1               Juvenile                3
# 435824                 4                Welcome                0
# 435825                 1               Juvenile                3
# 435826                 3                 Senior                0
#
#         Total Renewals          Age Range Home Library Code  \
# 42                   5     45 to 54 years                r3
# 53                 382     55 to 59 years                r3
# 83                   0     25 to 34 years                r3
# 118                  0     35 to 44 years                r3
# 163                 14     35 to 44 years                r3
# ...                ...                ...               ...
# 435822               0     35 to 44 years                r3
# 435823               7       0 to 9 years                r3
# 435824               0     55 to 59 years                r3
# 435825               1       0 to 9 years                r3
# 435826               0  75 years and over                r3
#
#        Home Library Definition Circulation Active Month  \
# 42                    Richmond                      May
# 53                    Richmond                      Jun
# 83                    Richmond                      Jun
# 118                   Richmond                      Feb
# 163                   Richmond                      Apr
# ...                        ...                      ...
# 435822                Richmond                      Apr
# 435823                Richmond                      Jul
# 435824                Richmond                      NaN
# 435825                Richmond                      Apr
# 435826                Richmond                      NaN
#
#         Circulation Active Year Notice Preference Code  \
# 42                       2023.0                      z
# 53                       2023.0                      z
# 83                       2023.0                      z
# 118                      2020.0                      z
# 163                      2023.0                      z
# ...                         ...                    ...
# 435822                   2023.0                    NaN
# 435823                   2023.0                    NaN
# 435824                      NaN                    NaN
# 435825                   2023.0                    NaN
# 435826                      NaN                    NaN
#
#        Notice Preference Definition  Provided Email Address  \
# 42                            Email                    True
# 53                            Email                    True
# 83                            Email                    True
# 118                           Email                    True
# 163                           Email                    True
# ...                             ...                     ...
# 435822                          NaN                   False
# 435823                          NaN                   False
# 435824                          NaN                   False
# 435825                          NaN                   False
# 435826                          NaN                   False
#
#         Year Patron Registered Within San Francisco County
# 42                        2023                       False
# 53                        2003                       False
# 83                        2017                       False
# 118                       2020                       False
# 163                       2023                       False
# ...                        ...                         ...
# 435822                    2023                         NaN
# 435823                    2023                         NaN
# 435824                    2019                         NaN
# 435825                    2023                         NaN
# 435826                    2023                         NaN
#
# [20656 rows x 14 columns]

# %%
data.isna().sum()
# Out:
# Patron Type Code                    0
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         912
# Home Library Code                   2
# Home Library Definition            30
# Circulation Active Month        39513
# Circulation Active Year         39513
# Notice Preference Code          42989
# Notice Preference Definition    42989
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County      1207
# dtype: int64

# %%
data['Age Range'].fillna("keine Angabe")
# Out:
# 0              keine Angabe
# 1              keine Angabe
# 2            45 to 54 years
# 3              keine Angabe
# 4              keine Angabe
#                 ...
# 436285       35 to 44 years
# 436286       10 to 19 years
# 436287       60 to 64 years
# 436288       35 to 44 years
# 436289    75 years and over
# Name: Age Range, Length: 436290, dtype: object

# %%
data.isna().sum()
# Out:
# Patron Type Code                    0
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         912
# Home Library Code                   2
# Home Library Definition            30
# Circulation Active Month        39513
# Circulation Active Year         39513
# Notice Preference Code          42989
# Notice Preference Definition    42989
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County      1207
# dtype: int64

# %%
df = data.dropna()

# %%
df.isna().sum()
# Out:
# Patron Type Code                0
# Patron Type Definition          0
# Total Checkouts                 0
# Total Renewals                  0
# Age Range                       0
# Home Library Code               0
# Home Library Definition         0
# Circulation Active Month        0
# Circulation Active Year         0
# Notice Preference Code          0
# Notice Preference Definition    0
# Provided Email Address          0
# Year Patron Registered          0
# Within San Francisco County     0
# dtype: int64

# %%
df.to_csv("/home/anni/Schreibtisch/2023-2024-Data-Librarian-AKC/Modul_3/data/Library_Usage_Clean.csv")

# %%
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_98343/3342542040.py in ?()
# ----> 1 df.rows
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
len(df)
# Out:
# 357838

# %%
len(data)
# Out:
# 436290

# %%
a = 436290
b = 357838

result = a - b


print("Gedropte NaN-Frames:", result)
# Out:
# Gedropte NaN-Frames: 78452

# %%
data.head(100)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  5                  Staff               53              15
# 1                  5                  Staff              480             378
# 2                  5                  Staff               70              33
# 3                  5                  Staff             3934            2140
# 4                  5                  Staff             1118            1035
# ..               ...                    ...              ...             ...
# 95                10                Visitor               11               0
# 96                 1               Juvenile                0               0
# 97                10                Visitor                0               0
# 98                 0                  Adult              111             113
# 99                16    Digital Access Card                0               0
#
#             Age Range Home Library Code Home Library Definition  \
# 0                 NaN                b2                 Bayview
# 1                 NaN                e9               Excelsior
# 2      45 to 54 years                n4              Noe Valley
# 3                 NaN                o2              Ocean View
# 4                 NaN                o7                  Ortega
# ..                ...               ...                     ...
# 95     35 to 44 years                a5                    Anza
# 96     10 to 19 years                 x                    Main
# 97  75 years and over                p1                    Park
# 98     45 to 54 years                p1                    Park
# 99     25 to 34 years                 x                    Main
#
#    Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                       Mar                   2023.0                      z
# 1                       Jun                   2023.0                      z
# 2                       Jan                   2023.0                      z
# 3                       Jul                   2023.0                      z
# 4                       Jul                   2023.0                      z
# ..                      ...                      ...                    ...
# 95                      Jun                   2023.0                      z
# 96                      NaN                      NaN                      z
# 97                      Feb                   2023.0                    NaN
# 98                      Jul                   2023.0                      z
# 99                      Mar                   2023.0                    NaN
#
#    Notice Preference Definition  Provided Email Address  \
# 0                         Email                    True
# 1                         Email                    True
# 2                         Email                    True
# 3                         Email                    True
# 4                         Email                    True
# ..                          ...                     ...
# 95                        Email                    True
# 96                        Email                    True
# 97                          NaN                   False
# 98                        Email                    True
# 99                          NaN                   False
#
#     Year Patron Registered Within San Francisco County
# 0                     2003                       False
# 1                     2003                       False
# 2                     2011                       False
# 3                     2003                       False
# 4                     2003                       False
# ..                     ...                         ...
# 95                    2023                       False
# 96                    2021                       False
# 97                    2022                       False
# 98                    2015                       False
# 99                    2023                       False
#
# [100 rows x 14 columns]
